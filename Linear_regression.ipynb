# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullah21079/CAS/blob/master/Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
Data = pd.read_excel(r'/content/gdrive/My Drive/Height and Width.xlsx')

# %%
display(pd.DataFrame(Data))
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 3496  69.296830  185.649086
# 3497  70.542201  210.198845
# 3498  73.912549  202.429960
# 3499  67.396021  144.277671
# 3500  72.738970  187.222909
#
# [3501 rows x 2 columns]

# %%
Data.rent[0:6]

# %%
x=Data[['Height']]

# %%
x.head(6)
# Out:
#       Height
# 0  73.847017
# 1  68.781904
# 2  74.110105
# 3  71.730978
# 4  69.881796
# 5  67.253016

# %%
y=Data[["Weight"]]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
xtrain,xtest,ytrain,ytest=tts(x,y,test_size=0.3,random_state=5)

# %%
xtrain.head()
# Out:
#          Height
# 3466  67.172828
# 828   66.653234
# 2234  65.077902
# 3245  65.035786
# 1298  69.702258

# %%
xtest.head()
# Out:
#          Height
# 2730  63.914541
# 2008  66.416414
# 840   69.016067
# 2635  71.948486
# 1721  71.196587

# %%
ytrain.head()
# Out:
#           Weight
# 3466  181.886241
# 828   160.147436
# 2234  165.313807
# 3245  168.618676
# 1298  177.149091

# %%
ytest.head()
# Out:
#           Weight
# 2730  167.842391
# 2008  193.601091
# 840   196.763907
# 2635  208.204435
# 1721  191.683842

# %%
from sklearn.linear_model import LinearRegression

# %%
N=LinearRegression()

# %%
N.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
M=N.coef_#y=mx+c

# %%
M
# Out:
# array([[6.00809929]])

# %%
c=N.intercept_

# %%
N.predict(xtest)
# Out:
# array([[156.22895255],
#        [171.26045447],
#        [186.87942774],
#        ...,
#        [205.60020285],
#        [186.14253731],
#        [219.24585226]])

# %%
Data["predicted Result"]=N.predict(x)

# %%
Data.head()
# Out:
#       Height      Weight  predicted Result
# 0  73.847017  241.893563        215.904254
# 1  68.781904  162.310473        185.472553
# 2  74.110105  212.740856        217.484915
# 3  71.730978  220.042470        203.190884
# 4  69.881796  206.349801        192.080812

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
pred=N.predict(xtest)

# %%
pred
# Out:
# array([[156.22895255],
#        [171.26045447],
#        [186.87942774],
#        ...,
#        [205.60020285],
#        [186.14253731],
#        [219.24585226]])

# %%
mse=mean_squared_error(ytest,pred)

# %%
mse
# Out:
# 102.60138482843213

# %%
mae=mean_absolute_error(ytest,pred)

# %%
mae
# Out:
# 8.061150778858023

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(50,35))
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Height_Width_Plot")
plt.scatter(xtrain,ytrain)
plt.plot(xtrain,N.predict(xtrain))
plt.scatter(xtrain,N.predict(xtrain),color="green")

# %%
import pickle as pk
import joblib as jb

# %%
pk.dump(N,open("first","wb"))

# %%
N2=pk.load(open("first","rb"))

# %%
N2.predict([[2000]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[11788.42261415]])

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
jb.dump(N,"Show")
# Out:
# ['Show']
